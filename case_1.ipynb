# %%
#importing libraries

import numpy as np
import pandas as pd
import seaborn as sns

# %%
emp= pd.read_csv('C:/Users/acer/Downloads/Compressed/Classification/Case study/Random Forest/Case 1/employee.csv')

# %%
emp.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
emp.describe(include='all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %%
emp.drop(['EmployeeCount','EmployeeNumber','Over18','StandardHours'],inplace=True,axis=1)

# %%
emp.loc[ emp['Attrition']== 'Yes' , 'Attrition' ] = 1
emp.loc[ emp['Attrition']== 'No' , 'Attrition' ] = 0

# %%
# for i in range(emp.shape[0]):
#     if emp.iloc[i,1] == 'Yes':
#         emp.iloc[i,1]=1
#     else:
#         emp.iloc[i,1]=0

# %%
emp.Attrition.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Attrition, dtype: int64

# %%
# defining y

y=emp['Attrition']

# %%
emp_dummies=pd.get_dummies(emp[emp.select_dtypes(include='object').columns.tolist()])

# %%
emp_dummies.head()
# Out:
#    BusinessTravel_Non-Travel  BusinessTravel_Travel_Frequently  \
# 0                          0                                 0
# 1                          0                                 1
# 2                          0                                 0
# 3                          0                                 1
# 4                          0                                 0
#
#    BusinessTravel_Travel_Rarely  Department_Human Resources  \
# 0                             1                           0
# 1                             0                           0
# 2                             1                           0
# 3                             0                           0
# 4                             1                           0
#
#    Department_Research & Development  Department_Sales  \
# 0                                  0                 1
# 1                                  1                 0
# ...

# %%
emp.drop('Attrition',axis=1,inplace=True)

# %%
emp_num=emp[emp.select_dtypes(include=[np.number]).columns.tolist()]
emp_num.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       1102                 1          2                        2
# 1   49        279                 8          1                        3
# 2   37       1373                 2          2                        4
# 3   33       1392                 3          4                        4
# 4   27        591                 2          1                        1
#
#    HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  ...  \
# 0          94               3         2                4           5993  ...
# 1          61               2         2                2           5130  ...
# 2          92               2         1                3           2090  ...
# 3          56               3         1                3           2909  ...
# 4          40               3         1                2           3468  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
emp_final = pd.concat([emp_dummies,emp_num],axis=1)
emp_final.head()
# Out:
#    BusinessTravel_Non-Travel  BusinessTravel_Travel_Frequently  \
# 0                          0                                 0
# 1                          0                                 1
# 2                          0                                 0
# 3                          0                                 1
# 4                          0                                 0
#
#    BusinessTravel_Travel_Rarely  Department_Human Resources  \
# 0                             1                           0
# 1                             0                           0
# 2                             1                           0
# 3                             0                           0
# 4                             1                           0
#
#    Department_Research & Development  Department_Sales  \
# 0                                  0                 1
# 1                                  1                 0
# ...

# %%
x=emp_final

# %%
from sklearn.model_selection import train_test_split
# x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# rf=RandomForestClassifier(n_estimators=100)     # n_estimators is equal to how many trees will be built

# %%
# rf.fit(x_train,y_train)

# %%
# y_pred=rf.predict_proba(x_test)[:,1]
# y_pred

# y_pred=rf.predict(x_test)

# %%
from sklearn import metrics
# roc=metrics.roc_auc_score(y_test,y_pred)
# print('roc_auc is',roc)
# print('accuracy is',metrics.accuracy_score(y_pred,y_test))
# print('recall is',metrics.recall_score(y_pred,y_test))
# print('precision is ',metrics.precision_score(y_pred,y_test))

# %%
# # again with 200 estimators

# rf1=RandomForestClassifier(n_estimators=200)
# rf1.fit(x_train,y_train)
# print(metrics.roc_auc_score(y_test,rf1.predict_proba(x_test)[:,1]))

# %%
# print(rf1.predict_proba(x_test)[:,1])

# %%
# hyperparameter search

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
x_train.shape
# Out:
# (1102, 51)

# %%
x_test.shape
# Out:
# (368, 51)

# %%
1102-368
# Out:
# 734

# %%
368/1102
# Out:
# 0.3339382940108893

# %%
x_train,x_val,y_train,y_val=train_test_split(x_train,y_train,test_size=368/1102,random_state=0)

# %%
x_train.shape
# Out:
# (734, 51)

# %%
x_val.shape
# Out:
# (368, 51)

# %%
# tress estimators

num_trees=[10,20,25,50,75,100,200,500,750,1000]

# %%
for tree in num_trees:
    rf=RandomForestClassifier(n_estimators=tree)
    rf.fit(x_train,y_train)
    print('trees =',tree,': auc is ',metrics.roc_auc_score(y_val,rf.predict_proba(x_val)[:,1]))
# Out:
# trees = 10 : auc is  0.6880437271062271
# trees = 20 : auc is  0.7329727564102564
# trees = 25 : auc is  0.7691163003663004
# trees = 50 : auc is  0.7382669413919414
# trees = 75 : auc is  0.7860004578754578
# trees = 100 : auc is  0.7878033424908425
# trees = 200 : auc is  0.7807348901098901
# trees = 500 : auc is  0.7851705586080586
# trees = 750 : auc is  0.7799049908424909
# trees = 1000 : auc is  0.7783882783882783

# %%
# now finally on test  # above roc is greatest on tree=100
rf1=RandomForestClassifier(n_estimators=100)
rf1.fit(x_train,y_train)
print('roc_auc is ',metrics.roc_auc_score(y_test,rf1.predict_proba(x_test)[:,1]))
# Out:
# roc_auc is  0.7553114571746384
